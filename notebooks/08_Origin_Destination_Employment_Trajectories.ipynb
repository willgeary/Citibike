# %%
import os
from os.path import join
import pandas as pd

# %%
input_dir = join("..", "data", "_model_inputs")

os.listdir(join(root, "data", "_model_inputs"))
# Out:
# ['.DS_Store',
#  'citibike_arrivals_monthly_by_neighborhood.csv',
#  'citibike_departures_monthly_by_neighborhood.csv',
#  'neighborhood_jobs.csv',
#  'neighborhood_NTACode.csv',
#  'neighborhood_number_of_citibike_stations.csv',
#  'neighborhood_population.csv',
#  'turnstile_monthly_by_neighborhood.csv']

# %%
df = pd.read_csv(join(input_dir, "neighborhood_jobs.csv"))

# %%
df.head()
# Out:
#   NTACode        NTAName   Borough  Year  Population  numStations  \
# 0    BK88   Borough Park  Brooklyn  2010      106357            0
# 1    QN52  East Flushing    Queens  2010       26982            0
# 2    QN48     Auburndale    Queens  2010       19996            0
# 3    QN51    Murray Hill    Queens  2010       51739            0
# 4    QN27  East Elmhurst    Queens  2010       23150            0
#
#    BX_departures  BK_departures  MN_departures  QN_departures  SI_departures  \
# 0              0          25542              0              0              0
# 1              0              0              0          10343              0
# 2              0              0              0           7777              0
# 3              0              0              0          18530              0
# 4              0              0              0           7899              0
#
#    BX_arrivals  BK_arrivals  MN_arrivals  QN_arrivals  SI_arrivals
# ...
