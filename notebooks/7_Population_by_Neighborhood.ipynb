# %% [markdown]
# # 2010 Population by Neighborhood

# %% [markdown]
# Data source: https://data.cityofnewyork.us/City-Government/New-York-City-Population-By-Neighborhood-Tabulatio/swpk-hqdp/data

# %%
import pandas as pd
import geopandas as gpd
from os.path import join
import os
import matplotlib.pyplot as plt

# %%
url = "https://data.cityofnewyork.us/api/views/swpk-hqdp/rows.csv?accessType=DOWNLOAD"

# %%
population = pd.read_csv(url)
population_2010 = population[population['Year'] == 2010]

# %%
skip_jersey_city = True

if skip_jersey_city == False:
    # Manually add jersey city population?
    # Source: https://www.google.com/publicdata/explore?ds=kf7tgg1uo9ude_&met_y=population&hl=en&dl=en
    JC_df = pd.DataFrame()
    JC_df['Borough'] = ["Jersey City"]
    JC_df['Year'] = [2010]
    JC_df['FIPS County Code'] = [0] # look this up later
    JC_df['NTA Code'] = ["JC"]
    JC_df['NTA Name'] = ["Jersey City"]
    JC_df['Population'] = [163422]

    population_2010 = pd.concat([population_2010, JC_df])

# %%
population_2010.reset_index(drop=True, inplace=True)

# %%
population_2010.sort_values(by='Population', ascending=False).head(10)
# Out:
#        Borough  Year  FIPS County Code NTA Code                  NTA Name  \
# 95   Manhattan  2010                61     MN12           Upper West Side
# 138     Queens  2010                81     QN28           Jackson Heights
# 82    Brooklyn  2010                47     BK88              Borough Park
# 58    Brooklyn  2010                47     BK42                  Flatbush
# 66    Brooklyn  2010                47     BK61       Crown Heights North
# 79    Brooklyn  2010                47     BK82             East New York
# 46    Brooklyn  2010                47     BK28          Bensonhurst West
# 139     Queens  2010                81     QN29                  Elmhurst
# 114  Manhattan  2010                61     MN36  Washington Heights South
# 128     Queens  2010                81     QN17              Forest Hills
#
#      Population
# 95       132378
# 138      108152
# 82       106357
# 58       105804
# 66       103169
# 79        91958
# 46        88727
# 139       88427
# 114       84438
# 128       83728

# %%
root = ".."
output_dir = join(root, "data", "population")
# Make data directory
if not os.path.exists(output_dir):
    os.mkdir(output_dir)

# %%
population_2010.to_csv(join(output_dir, "population_2010.csv"))

# %% [markdown]
# # Join to neighborhoods and make choropleth map

# %%
inputfile = join(root, "data", "neighborhood_tabulation_areas", "nyc_neighborhoods_4326",
                 "nyc_neighborhoods_4326.shp")
neighborhoods = gpd.read_file(inputfile)

# %%
population_2010.index = population_2010['NTA Code']

# %%
neighborhoods.index = neighborhoods['NTACode']

# %%
neighborhoods = neighborhoods.join(population_2010, how='left')

# %%
f, ax = plt.subplots(1, figsize=(15,15))
neighborhoods.plot(ax=ax,figsize=(15,15), linewidth=0.2, edgecolor='0.5', scheme="fisher_jenks", column = 'Population')
ax.set_axis_off()
plt.axis('equal')
plt.title("NYC Neighborhoods by Population (2010)")
plt.show()

# %%
neighborhoods.crs
# Out:
# {'init': 'epsg:4326'}

# %%
neighborhoods.head()
# Out:
#          BoroCode  BoroName CountyFIPS NTACode        NTAName    Shape_Leng  \
# NTACode
# BK88            3  Brooklyn        047    BK88   Borough Park  39247.228028
# QN52            4    Queens        081    QN52  East Flushing  25843.364936
# QN48            4    Queens        081    QN48     Auburndale  32446.878673
# QN51            4    Queens        081    QN51    Murray Hill  33266.904811
# QN27            4    Queens        081    QN27  East Elmhurst  19816.712323
#
#            Shape_Area                                           geometry  \
# NTACode
# BK88     5.400502e+07  POLYGON ((-73.97604935657381 40.63127590564677...
# QN52     2.945438e+07  POLYGON ((-73.79493246233996 40.75779803007455...
# QN48     3.416422e+07  POLYGON ((-73.77573836927098 40.74332564716399...
# QN51     5.248828e+07  POLYGON ((-73.80379022888246 40.77561011179249...
# QN27     1.972685e+07  POLYGON ((-73.86109724335759 40.7636644770869,...
#
#           Borough  Year  FIPS County Code NTA Code       NTA Name  Population
# NTACode
# BK88     Brooklyn  2010                47     BK88   Borough Park      106357
# QN52       Queens  2010                81     QN52  East Flushing       26982
# QN48       Queens  2010                81     QN48     Auburndale       19996
# QN51       Queens  2010                81     QN51    Murray Hill       51739
# QN27       Queens  2010                81     QN27  East Elmhurst       23150

# %%
root = ".."
neighborhoods[['NTACode', 'NTAName', 'geometry', 'Borough', 'Year', 'Population']].to_file(join(root, "data", "neighborhood_tabulation_areas", "nyc_neighborhoods_population"))
